# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data = pd.read_csv('30.IMDB-Movie-Data.csv')
data
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
data['Metascore'].mean()
# Out:
# 58.98504273504273

# %%
# 求导演的人数，去重
data_director = np.array(data['Director'])
print(data_director.shape)
print(data['Director'].unique().shape)
print(np.unique(data_director).shape)
print(data.groupby('Director').all().shape)
pd.unique()
# Out:
# (1000,)
# (644,)
# (644,)
# (644, 11)

# %%
data.head(10)
# Out:
#    Rank                    Title                       Genre  \
# 0     1  Guardians of the Galaxy     Action,Adventure,Sci-Fi
# 1     2               Prometheus    Adventure,Mystery,Sci-Fi
# 2     3                    Split             Horror,Thriller
# 3     4                     Sing     Animation,Comedy,Family
# 4     5            Suicide Squad    Action,Adventure,Fantasy
# 5     6           The Great Wall    Action,Adventure,Fantasy
# 6     7               La La Land          Comedy,Drama,Music
# 7     8                 Mindhorn                      Comedy
# 8     9       The Lost City of Z  Action,Adventure,Biography
# 9    10               Passengers     Adventure,Drama,Romance
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# ...

# %%
# 求演员的人数，分割后去重
data_actors = data['Actors']
a = []
# list(map(lambda x: a.extend(x.split(',')), data_actors))
list(map(lambda x, y : y.extend(x.split(',')), data_actors, c := [a]*len(data_actors)))
print(a)
print(np.array(a).shape)
print(np.unique(np.array(a)).shape)
# Out:
# ['Chris Pratt', ' Vin Diesel', ' Bradley Cooper', ' Zoe Saldana', 'Noomi Rapace', ' Logan Marshall-Green', ' Michael Fassbender', ' Charlize Theron', 'James McAvoy', ' Anya Taylor-Joy', ' Haley Lu Richardson', ' Jessica Sula', 'Matthew McConaughey', 'Reese Witherspoon', ' Seth MacFarlane', ' Scarlett Johansson', 'Will Smith', ' Jared Leto', ' Margot Robbie', ' Viola Davis', 'Matt Damon', ' Tian Jing', ' Willem Dafoe', ' Andy Lau', 'Ryan Gosling', ' Emma Stone', ' Rosemarie DeWitt', ' J.K. Simmons', 'Essie Davis', ' Andrea Riseborough', ' Julian Barratt', 'Kenneth Branagh', 'Charlie Hunnam', ' Robert Pattinson', ' Sienna Miller', ' Tom Holland', 'Jennifer Lawrence', ' Chris Pratt', ' Michael Sheen', 'Laurence Fishburne', 'Eddie Redmayne', ' Katherine Waterston', ' Alison Sudol', 'Dan Fogler', 'Taraji P. Henson', ' Octavia Spencer', ' Janelle Monáe', 'Kevin Costner', 'Felicity Jones', ' Diego Luna', ' Alan Tudyk', ' Donnie Yen', "Auli'i Cravalho", ' Dwayne Johnson', ' Rachel House', ' 
# ...

# %%
# stack演示
data_demo = {'City': ['BJ', 'SH', 'GZ', 'SZ', 'HK'],
        '2011': [17000, 19000, 16000, 19000, 18000],
        '2012': [21000, 20000, 19000, 17000, 21500]}

df = pd.DataFrame(data_demo)

# 使用stack函数
df_stack = df.set_index('City').stack().reset_index()

print(df.set_index('City'))
print(df.set_index('City').stack())
print(df.set_index('City').stack().reset_index())

df_unstack = df_stack.set_index(['City', 'level_1']).unstack()

print(df_unstack)
# Out:
#        2011   2012
# City
# BJ    17000  21000
# SH    19000  20000
# GZ    16000  19000
# SZ    19000  17000
# HK    18000  21500
# City
# BJ    2011    17000
#       2012    21000
# SH    2011    19000
#       2012    20000
# GZ    2011    16000
#       2012    19000
# SZ    2011    19000
#       2012    17000
# HK    2011    18000
#       2012    21500
# dtype: int64
#   City level_1      0
# 0   BJ    2011  17000
# 1   BJ    2012  21000
# 2   SH    2011  19000
# 3   SH    2012  20000
# 4   GZ    2011  16000
# 5   GZ    2012  19000
# 6   SZ    2011  19000
# 7   SZ    2012  17000
# 8   HK    2011  18000
# 9   HK    2012  21500
#              0
# level_1   2011   2012
# City
# BJ       17000  21000
# GZ       16000  19000
# HK       18000  21500
# SH       19000  20000
# SZ       19000  17000

# %%
# 画图统计平衡和票房
data['Rating'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data['Revenue (Millions)'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data_draw = data[['Revenue (Millions)','Rating']].dropna()
data_draw_sort_rating = data_draw.sort_values(by='Rating')
data_draw_sort_revenue = data_draw.sort_values(by='Revenue (Millions)')
plt.figure()
plt.plot(data_draw_sort_rating['Rating'], data_draw_sort_rating['Revenue (Millions)'])
# plt.plot(data_draw_sort_revenue['Revenue (Millions)'],data_draw_sort_revenue['Rating'])

# %%
# 统计电影分类
genre_ls = list(map(lambda x:x.split(','), data['Genre']))
genre_ls = [j for i in genre_ls for j in i]
genre_np = np.array(genre_ls)
genre_np = np.unique(genre_np)

# sorted([data['Genre'].str.contains(i).value_counts()[1] for i in genre_np])
[data['Genre'].value_counts() for i in genre_np]
data['Genre'].value_counts('213124')
# Out:
# Action,Adventure,Sci-Fi    0.050
# Drama                      0.048
# Comedy,Drama,Romance       0.035
# Comedy                     0.032
# Drama,Romance              0.031
#                            ...
# Action,Comedy,Family       0.001
# Action,Crime,Fantasy       0.001
# Comedy,Mystery             0.001
# Adventure,Comedy,Horror    0.001
# Comedy,Family,Fantasy      0.001
# Name: Genre, Length: 207, dtype: float64
